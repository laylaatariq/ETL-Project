# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
hot_stuff = "hot_stuff_2.csv"
hot_stuff_df = pd.read_csv(hot_stuff)
hot_stuff_df.head()
# Out:
#                                                  url      weekid  \
# 0  https://www.billboard.com/charts/hot-100/2019-...  12/28/2019
# 1  https://www.billboard.com/charts/hot-100/2019-...  12/28/2019
# 2  https://www.billboard.com/charts/hot-100/2019-...  12/28/2019
# 3  https://www.billboard.com/charts/hot-100/2019-...  12/28/2019
# 4  https://www.billboard.com/charts/hot-100/2019-...  12/28/2019
#
#    week_position                               song       performer  \
# 0              1    All I Want For Christmas Is You    Mariah Carey
# 1              2  Rockin' Around The Christmas Tree      Brenda Lee
# 2              3                            Circles     Post Malone
# 3              4                            Roxanne  Arizona Zervas
# 4              5                Futsal Shuffle 2020    Lil Uzi Vert
#
#                                         songid  instance  \
# 0  All I Want For Christmas Is YouMariah Carey         9
# ...

# %%
top_50 = "top50.csv"
top_50_df = pd.read_csv(top_50)
top_50_df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-00cea309ce99> in <module>
#       1 top_50 = "top50.csv"
# ----> 2 top_50_df = pd.read_csv(top_50)
#       3 top_50_df.head()
#
# ...
